# %%
x = -15132376222941642752 
k = 12
r = (x**4-x**2+1)
q = ((x-1)**2)//3 * r + x
h = (q**k - 1) // r

lam = 4002409555221667393417789825735904156556882819939007885332058136124031650490837864442687629129030796414117214202539
m = lam // r
p = 5044125407647214251
h3 = ...

s = 2
t = (p^12 - 1) // 3^s

assert(h == 27 * p * h3)
assert(m == 3 * p^2)

assert(gcd(3, h3) == 1)
assert(gcd(p^2, h3) == 1)
assert(gcd(3, h3) == 1)
assert(gcd(p, h3) == 1)
assert(gcd(p, 27 * h3) == 1)
assert(gcd(27, p * h3) == 1)

F = GF(q)
Fq12.<u> = GF(q^12)
ONE = Fq12(1)

w27 = ONE.nth_root(27); 
wp = ONE.nth_root(p);

assert(w27^9 != ONE)

# %%
from random import randrange
def sample_27th_root(): 
    i = randrange(27)
    return [w27^i, i]

def sample_pth_root(): 
    i = randrange(p)
    return [wp^i, i]

def sample_h3_root():
    x = Fq12.random_element(); 
    x = x^r 
    x = x^27 
    x = x^p 
    
    assert(x^h3 == ONE)
    
    return x

# %%
def has_27th_root_contribution(x): 
    # checks if x has a 27th root of unity contribution 
    try: 
        a = x.nth_root(3)
        return False
    except: 
        return True
    
def has_pth_root_contribution(x): 
    # checks if x has a pth root of unity contribution 
    try: 
        x.nth_root(p)
        return False
    except: 
        return True
    
def get_pth_root_inverse(x): 
    if not has_pth_root_contribution(x): 
        return ONE 
    
    v = 27 * h3 
    wj = x^v 
    
    v_inv = inverse_mod(v, p)
    s = (-1 * v_inv) % p
    
    return wj^s

def get_27th_root_inverse(x): 
    if not has_27th_root_contribution(x): 
        return ONE 
    
    v = p * h3 
    wj = x^v 
    
    v_inv = inverse_mod(v, 27)
    s = (-1 * v_inv) % 27
    
    return wj^s

# %%
(q^k - 1)/(gcd(p, q^k - 1))
# Out:
# ...

# %%
for i in range(300):
    f = Fq12.random_element()
    assert((f^((q^k - 1)/(gcd(3, q^k - 1))) == 1) == (not has_27th_root_contribution(f)))
    assert((f^((q^k - 1)/(gcd(p, q^k - 1))) == 1) == (not has_pth_root_contribution(f)))
    print('step: ', i)
# Out:
# step:  0
# step:  1
# step:  2
# step:  3
# step:  4
# step:  5
# step:  6
# step:  7
# step:  8
# step:  9
# step:  10
# step:  11
# step:  12
# step:  13
# step:  14
# step:  15
# step:  16
# step:  17
# step:  18
# step:  19
# step:  20
# step:  21
# step:  22
# step:  23
# step:  24
# step:  25
# step:  26
# step:  27
# step:  28
# step:  29
# step:  30
# step:  31
# step:  32
# step:  33
# step:  34
# step:  35
# step:  36
# step:  37
# step:  38
# step:  39
# step:  40
# step:  41
# step:  42
# step:  43
# step:  44
# step:  45
# step:  46
# step:  47
# step:  48
# step:  49
# step:  50
# step:  51
# step:  52
# step:  53
# step:  54
# step:  55
# step:  56
# step:  57
# step:  58
# step:  59
# step:  60
# step:  61
# step:  62
# step:  63
# step:  64
# step:  65
# step:  66
# step:  67
# step:  68
# step:  69
# step:  70
# step:  71
# step:  72
# step:  73
# step:  74
# step:  75
# step:  76
# step:  77
# step:  78
# step:  79
# step:  80
# step:  81
# step:  82
# step:  83
# step:  84
# step:  85
# step:  86
# step:  87
# step:  88
# step:  89
# step:  90
# step:  91
# step:  92
# step:  93
# step:  94
# step:  95
# step:  96
# step:  97
# step:  98
# step:  99
# step:  100
# step:  101
# step:  102
# step:  103
# step:  104
# step:  105
# step:  106
# step:  107
# step:  108
# step:  109
# step:  110
# step:  111
# step:  112
# step:  113
# step:  114
# step:  115
# step:  116
# step:  117
# step:  118
# step:  119
# step:  120
# step:  121
# step:  122
# step:  123
# step:  124
# step:  125
# step:  126
# step:  127
# step:  128
# step:  129
# step:  130
# step:  131
# step:  132
# step:  133
# step:  134
# step:  135
# step:  136
# step:  137
# step:  138
# step:  139
# step:  140
# step:  141
# step:  142
# step:  143
# step:  144
# step:  145
# step:  146
# step:  147
# step:  148
# step:  149
# step:  150
# step:  151
# step:  152
# step:  153
# step:  154
# step:  155
# step:  156
# step:  157
# step:  158
# step:  159
# step:  160
# step:  161
# step:  162
# step:  163
# step:  164
# step:  165
# step:  166
# step:  167
# step:  168
# step:  169
# step:  170
# step:  171
# step:  172
# step:  173
# step:  174
# step:  175
# step:  176
# step:  177
# step:  178
# step:  179
# step:  180
# step:  181
# step:  182
# step:  183
# step:  184
# step:  185
# step:  186
# step:  187
# step:  188
# step:  189
# step:  190
# step:  191
# step:  192
# step:  193
# step:  194
# step:  195
# step:  196
# step:  197
# step:  198
# step:  199
# step:  200
# step:  201
# step:  202
# step:  203
# step:  204
# step:  205
# step:  206
# step:  207
# step:  208
# step:  209
# step:  210
# step:  211
# step:  212
# step:  213
# step:  214
# step:  215
# step:  216
# step:  217
# step:  218
# step:  219
# step:  220
# step:  221
# step:  222
# step:  223
# step:  224
# step:  225
# step:  226
# step:  227
# step:  228
# step:  229
# step:  230
# step:  231
# step:  232
# step:  233
# step:  234
# step:  235
# step:  236
# step:  237
# step:  238
# step:  239
# step:  240
# step:  241
# step:  242
# step:  243
# step:  244
# step:  245
# step:  246
# step:  247
# step:  248
# step:  249
# step:  250
# step:  251
# step:  252
# step:  253
# step:  254
# step:  255
# step:  256
# step:  257
# step:  258
# step:  259
# step:  260
# step:  261
# step:  262
# step:  263
# step:  264
# step:  265
# step:  266
# step:  267
# step:  268
# step:  269
# step:  270
# step:  271
# step:  272
# step:  273
# step:  274
# step:  275
# step:  276
# step:  277
# step:  278
# step:  279
# step:  280
# step:  281
# step:  282
# step:  283
# step:  284
# step:  285
# step:  286
# step:  287
# step:  288
# step:  289
# step:  290
# step:  291
# step:  292
# step:  293
# step:  294
# step:  295
# step:  296
# step:  297
# step:  298
# step:  299

# %%
for i in range(300): 
    f = Fq12.random_element()
    f = f^r # it will always come as r-th residue in the honest execution

    wp_shift = get_pth_root_inverse(f)
    w27_shift = get_27th_root_inverse(f)
    
    f_shifted = f * wp_shift * w27_shift

    root = f_shifted.nth_root(lam)
    assert(f_shifted, root^lam)
    print('step: ', i)
# Out:
# step:  0
# step:  1
# step:  2
# step:  3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       6 w27_shift = get_27th_root_inverse(f)
#       8 f_shifted = f * wp_shift * w27_shift
# ---> 10 root = f_shifted.nth_root(lam)
#      11 assert(f_shifted, root**lam)
#      12 print('step: ', i)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/finite_rings/element_base.pyx:942, in sage.rings.finite_rings.element_base.FinitePolyExtElement.nth_root (build/cythonized/sage/rings/finite_rings/element_base.c:14023)()
#     940         raise NotImplementedError
#     941     n = Integer(n)
# --> 942     return self._nth_root_common(n, all, algorithm, cunningham)
#     943
#     944 def pth_power(self, int k = 1):
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/finite_rings/element_base.pyx:125, in sage.rings.finite_rings.element_base.FiniteRingElement._nth_root_common (build/cythonized/sage/rings/finite_rings/element_base.c:6484)()
#     123 x = (1 + z) // r**v
#     124 if k == v:
# --> 125     self = self**x
#     126 else:
#     127     # We need an element of order r^k (g^h in Johnston's article)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/finite_rings/element_pari_ffelt.pyx:860, in sage.rings.finite_rings.element_pari_ffelt.FiniteFieldElement_pari_ffelt.__pow__ (build/cythonized/sage/rings/finite_rings/element_pari_ffelt.c:13205)()
#     858 exp = Integer(exp).__pari__()
#     859 cdef FiniteFieldElement_pari_ffelt x = self._new()
# --> 860 sig_on()
#     861 x.construct(FF_pow(self.val, (<pari_gen>exp).g))
#     862 return x
#
# KeyboardInterrupt:

# %%
f = Fq12.random_element()
f = f^r # it will always come as r-th residue in the honest execution

wp_shift = get_pth_root_inverse(f)
w27_shift = get_27th_root_inverse(f)

c = f * wp_shift * w27_shift

# %%
q = 7
F = IntegerModRing(q)

# %%
a = wp
# a = Fq12.random_element()
s = 2
_t = (q - 1) / 3^s
_k = (_t - 1) / 3

# Cubic Tonelli-Shanks https://eprint.iacr.org/2009/457.pdf
assert(q - 1 == 3^s * _t)
# b = Fq12.random_element()
# b = F.random_element()
b = w27
c = b^_t
r = a^_t

h = 1
cc = c^(3^(s - 1))
c = c^(-1)

for i in range(0, s):
    d = r^(3^(s - i - 1))
    if d == cc:
        h *= c
        r *= c^3
    elif d != F(1):
        h *= c^2
        r *= (c^3)^2
    c = c^3

# assert((a^_t)^(-1) == h^3)
r = a^_k * h
if _t == 3 * _k + 1:
    r = r^(-1)

assert(r^3 == a)
